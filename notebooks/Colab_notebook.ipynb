# %% [markdown]
# ## Install Video Object Detection Package

# %%
# Clone the project repository
# !git clone https://github.com/evaezpour/video_object_detection.git

# Change directory to the project
# %cd video_object_detection

# Install dependencies
# !pip install -r requirements.txt

# !pip install -e .

# Change back to the original directory
# %cd ..

# %% [markdown]
# ## Install GroundingDINO

# %%
import sys


# Clone the GroundingDINO project
# !git clone https://github.com/IDEA-Research/GroundingDINO.git

# Change directory to the GroundingDINO project
# %cd GroundingDINO

# Install dependencies
# !pip install -e .

# Add the GroundingDINO directory to the Python path
sys.path.append('/content/GroundingDINO')

# Change back to the original directory
# %cd ..

# %%
import os
os.chdir('video_object_detection')

# %% [markdown]
# ## Video_Object_Detection Demo

# %%
from video_object_detection.object_detector.video_processor import process_video
from IPython.display import HTML


input_video_path = './object_detector/input_video/street_trim.mp4'
output_video_path = './object_detector/output_video/output_street_black.mp4'
text_prompt = 'car wheels'

process_video(input_video_path, output_video_path, text_prompt)
